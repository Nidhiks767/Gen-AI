# %% [markdown]
# Lab 8 – Using Meta LLaMA-3 Models (Cloud & Local Deployment)

# %%
# !pip install groq replicate requests pandas --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 4.5 MB/s eta 0:00:00

# %%
from groq import Groq
import replicate
import os
import requests
import csv
import pandas as pd
import time

# %%
GROQ_API_KEY = "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"

client = Groq(api_key=GROQ_API_KEY)

print("Groq client initialized successfully")
# Out:
# Groq client initialized successfully

# %%
prompt = "Explain Large Language Models in simple terms."

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

output = response.choices[0].message.content

print("Prompt:\n", prompt)
print("\nGenerated Response:\n", output)
# Out:
# Prompt:
#  Explain Large Language Models in simple terms.
#
# Generated Response:
#  **What are Large Language Models (LLMs)?**
#
# Large Language Models are sophisticated computer programs designed to understand and generate human-like language. Think of them as super-smart language learners that can read, write, and even communicate in a way that's similar to humans.
#
# **How do LLMs work?**
#
# LLMs use a type of artificial intelligence (AI) called deep learning. They're trained on a massive dataset of texts, which can be anything from books, articles, to social media posts. This training data is used to create a complex neural network that can recognize patterns and relationships in language.
#
# **Key Components of LLMs:**
#
# 1. **Neural Network**: A network of interconnected nodes (or "neurons") that process and transform input data into meaningful output.
# 2. **Training Data**: A massive dataset of texts used to train the LLM.
# ...

# %%
prompt = """
Explain the architecture of transformer models
and the role of self-attention in deep learning.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt}]
)

output = response.choices[0].message.content

print(output)
# Out:
# **Transformer Architecture**
#
# The Transformer model, introduced in the paper "Attention is All You Need" by Vaswani et al. in 2017, has revolutionized the field of natural language processing (NLP) and has since been applied to various tasks such as image and speech processing. The Transformer architecture is primarily composed of three main components:
#
# ### 1. Encoder
#
# The encoder takes in a sequence of tokens (e.g., words, characters, or subwords) as input and outputs a sequence of vectors. The encoder consists of multiple layers, with each layer containing two sub-layers:
#
# *   **Self-Attention Mechanism:** This is the core component of the Transformer architecture. It allows the model to attend to different parts of the input sequence when generating the output.
# *   **Position-wise Feed-Forward Network:** This is a fully connected feed-forward network that takes the output of the self-attention sub-layer as input and applies a linear transformation.
#
# ...

# %%
prompt = "Explain neural networks."

start_time = time.time()

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt}]
)

end_time = time.time()

print(response.choices[0].message.content)
print("\nResponse Time:", round(end_time-start_time,2), "seconds")
# Out:
# **What are Neural Networks?**
#
# Neural networks are computational models inspired by the structure and function of the human brain. They are composed of layers of interconnected nodes or "neurons" that process and transmit information. Each node applies a non-linear transformation to the input it receives from the previous layer, allowing the network to learn and represent complex relationships between inputs and outputs.
#
# **How Do Neural Networks Work?**
#
# A neural network works as follows:
#
# 1. **Input Layer**: The input layer receives the input data, which is then passed to the next layer.
# 2. **Hidden Layers**: The hidden layers are where the neural network learns to represent the input data in a more abstract and hierarchical manner. Each layer consists of multiple nodes (neurons) that apply a non-linear transformation to the input it receives from the previous layer.
# ...

# %%
prompt = "Explain differences between LLaMA and GPT models."

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt}]
)

output = response.choices[0].message.content

with open("llama3_cloud_output.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Prompt", "Output"])
    writer.writerow([prompt, output])

print("File saved successfully!")
# Out:
# File saved successfully!
